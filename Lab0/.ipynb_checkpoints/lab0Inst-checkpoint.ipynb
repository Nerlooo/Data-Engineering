# %%
import findspark, pyspark
from pyspark.sql import SparkSession
findspark.init()
spark = SparkSession.builder.appName("de1-check").getOrCreate()
print("Spark:", spark.version)
print("PySpark:", pyspark.__version__)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/10/10 15:50:44 WARN Utils: Your hostname, MacBook-Air-de-Lorenzo.local, resolves to a loopback address: 127.0.0.1; using 147.215.206.38 instead (on interface en0)
# 25/10/10 15:50:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/10 15:50:44 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Spark: 4.0.1
# PySpark: 4.0.1

# %%
df = spark.read.option("header","true").csv("data/sample.csv")
df.show(5)
df.explain("formatted")
# Out:
# ++
# ||
# ++
# ++
#
# == Physical Plan ==
# Scan csv  (1)
#
#
# (1) Scan csv
# Output: []
# Batched: false
# Location: InMemoryFileIndex [file:/Users/lorenzo/Documents/Cours/E4FD/Data Engineering/data/sample.csv]
# ReadSchema: struct<>
